# %% [markdown]
# # Pandas:
# ### - Calling APIs using Python

# %% [markdown]
# <strong> <h2> Run The Following Code </h2> </strong>
#
# Hit SHIFT + ENTER when your cusor is inside the cell of code.<br/>

# %% [markdown]
# > Import the packages

# %%
import pandas as pd
import requests

# %% [markdown]
# ## Calling API Example 1

# %% [markdown]
# > 1. Open this url in your browser: https://data.gov.sg/dataset/list-of-government-markets-hawker-centres
# > 2. Click on the "Data API" button on top rigth corner to see resource_id for this dataset
# > 3. Use **requests** package to call this API and get all first 5 rows of data

# %%
# Option A - Manually construct the request URL
url_full = 'https://data.gov.sg/api/action/datastore_search?resource_id=8f6bba57-19fc-4f36-8dcf-c0bda382364d&limit=5'

response = requests.get(url_full)

# %%
# Option B - (Recommneded) passing a dictionary to .get() method in requests to construct the request url
url_base = 'https://data.gov.sg/api/action/datastore_search'

parameters = {
    'resource_id' : '8f6bba57-19fc-4f36-8dcf-c0bda382364d',
    'limit': '5'
}
response = requests.get(url_base, params=parameters)

# %%
# Check the url that sent to the API server
response.url
# Out:
# 'https://data.gov.sg/api/action/datastore_search?resource_id=8f6bba57-19fc-4f36-8dcf-c0bda382364d&limit=5'

# %%
# Check the status of the request
response.status_code
# Out:
# 200

# %%
# View the json text returned by the API server
response_dict = response.json()
response_dict
# Out:
# {'help': 'https://data.gov.sg/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'resource_id': '8f6bba57-19fc-4f36-8dcf-c0bda382364d',
#   'fields': [{'type': 'int4', 'id': '_id'},
#    {'type': 'text', 'id': 'name_of_centre'},
#    {'type': 'text', 'id': 'location_of_centre'},
#    {'type': 'text', 'id': 'type_of_centre'},
#    {'type': 'text', 'id': 'owner'},
#    {'type': 'numeric', 'id': 'no_of_stalls'},
#    {'type': 'numeric', 'id': 'no_of_cooked_food_stalls'},
#    {'type': 'numeric', 'id': 'no_of_mkt_produce_stalls'}],
#   'records': [{'location_of_centre': '2, Adam Road, S(289876)',
#     'no_of_cooked_food_stalls': '32',
#     'no_of_mkt_produce_stalls': '0',
#     'name_of_centre': 'Adam Road Food Centre',
#     'type_of_centre': 'HC',
#     'no_of_stalls': '32',
#     'owner': 'Government',
#     '_id': 1},
#    {'location_of_centre': 'National Development Building, Annex B, Telok Ayer Street, S(069111)',
#     'no_of_cooked_food_stalls': '134',
#     'no_of_mkt_produce_stalls': '1',
#     'name_of_centre': 'Amoy Street Food Centre',
#     'type_of_centre': 'HC',
#     'no_of_stalls': '135',
#     'owner': 'Government',
#     '_id': 2},
#    {'location_of_centre': '1, Bedok Road, S(469572)',
#     'no_of_cooked_food_stalls': '32',
#     'no_of_mkt_produce_stalls': '0',
#     'name_of_centre': 'Bedok Food Centre',
#     'type_of_centre': 'HC',
#     'no_of_stalls': '32',
#     'owner': 'Government',
#     '_id': 3},
#    {'location_of_centre': '38A, Beo Crescent, S(169982)',
#     'no_of_cooked_food_stalls': '32',
#     'no_of_mkt_produce_stalls': '62',
#     'name_of_centre': 'Beo Crescent Market',
#     'type_of_centre': 'MHC',
#     'no_of_stalls': '94',
#     'owner': 'Government',
#     '_id': 4},
#    {'location_of_centre': '166, Jalan Besar, S(208877)',
#     'no_of_cooked_food_stalls': '66',
#     'no_of_mkt_produce_stalls': '0',
#     'name_of_centre': 'Berseh Food Centre',
#     'type_of_centre': 'HC',
#     'no_of_stalls': '66',
#     'owner': 'Government',
#     '_id': 5}],
#   '_links': {'start': '/api/action/datastore_search?limit=5&resource_id=8f6bba57-19fc-4f36-8dcf-c0bda382364d',
#    'next': '/api/action/datastore_search?offset=5&limit=5&resource_id=8f6bba57-19fc-4f36-8dcf-c0bda382364d'},
#   'limit': 5,
#   'total': 107}}

# %% [markdown]
# > The json text above is a nested-dictionary <br>
# > Picture below shows the structure in a visual form
#
# > ![](hawker_structure.png)

# %%
# Traverse the dictionary to the level where the main records are located
response_dict['result']['total']
# Out:
# 107

# %%
# Traverse the dictionary to the level where the main records are located
records = response_dict['result']['records']
records
# Out:
# [{'location_of_centre': '2, Adam Road, S(289876)',
#   'no_of_cooked_food_stalls': '32',
#   'no_of_mkt_produce_stalls': '0',
#   'name_of_centre': 'Adam Road Food Centre',
#   'type_of_centre': 'HC',
#   'no_of_stalls': '32',
#   'owner': 'Government',
#   '_id': 1},
#  {'location_of_centre': 'National Development Building, Annex B, Telok Ayer Street, S(069111)',
#   'no_of_cooked_food_stalls': '134',
#   'no_of_mkt_produce_stalls': '1',
#   'name_of_centre': 'Amoy Street Food Centre',
#   'type_of_centre': 'HC',
#   'no_of_stalls': '135',
#   'owner': 'Government',
#   '_id': 2},
#  {'location_of_centre': '1, Bedok Road, S(469572)',
#   'no_of_cooked_food_stalls': '32',
#   'no_of_mkt_produce_stalls': '0',
#   'name_of_centre': 'Bedok Food Centre',
#   'type_of_centre': 'HC',
#   'no_of_stalls': '32',
#   'owner': 'Government',
#   '_id': 3},
#  {'location_of_centre': '38A, Beo Crescent, S(169982)',
#   'no_of_cooked_food_stalls': '32',
#   'no_of_mkt_produce_stalls': '62',
#   'name_of_centre': 'Beo Crescent Market',
#   'type_of_centre': 'MHC',
#   'no_of_stalls': '94',
#   'owner': 'Government',
#   '_id': 4},
#  {'location_of_centre': '166, Jalan Besar, S(208877)',
#   'no_of_cooked_food_stalls': '66',
#   'no_of_mkt_produce_stalls': '0',
#   'name_of_centre': 'Berseh Food Centre',
#   'type_of_centre': 'HC',
#   'no_of_stalls': '66',
#   'owner': 'Government',
#   '_id': 5}]

# %%
# Check the number of records
len(records)
# Out:
# 5

# %%
# Use .json_normalize from Pandas to convert the dictionary into a DataFrame
pd.json_normalize(records)
# Out:
#                                   location_of_centre no_of_cooked_food_stalls  \
# 0                            2, Adam Road, S(289876)                       32
# 1  National Development Building, Annex B, Telok ...                      134
# 2                           1, Bedok Road, S(469572)                       32
# 3                       38A, Beo Crescent, S(169982)                       32
# 4                        166, Jalan Besar, S(208877)                       66
#
#   no_of_mkt_produce_stalls           name_of_centre type_of_centre  \
# 0                        0    Adam Road Food Centre             HC
# 1                        1  Amoy Street Food Centre             HC
# 2                        0        Bedok Food Centre             HC
# 3                       62      Beo Crescent Market            MHC
# 4                        0       Berseh Food Centre             HC
#
#   no_of_stalls       owner  _id
# 0           32  Government    1
# 1          135  Government    2
# 2           32  Government    3
# 3           94  Government    4
# 4           66  Government    5

# %%
# Use .json_normalize from Pandas to convert the dictionary into a DataFrame 
# Store into a variable called "df_hawker"
df_hawker = pd.json_normalize(records)

# %% [markdown]
# ## Calling API Example 2: with Parameters

# %% [markdown]
# > 1. Open this url in your browser: https://www.onemap.gov.sg/docs/#onemap-rest-apis
# > 2. Understand the parameters (required and optional) of the "search" endpoint from OneMap API
# > 3. Use **requests** package to call this API and get all first 5 rows of data

# %% [markdown]
# > ![apiexp](onemap_search.png)

# %%
# Try to call the API (Case-sensitive Parameters not match)

url_base = 'https://developers.onemap.sg/commonapi/search'

parameters = {
    'searchval' : 'Adam Road Food Centre',
    'returngeom': 'Y',
    'getAddrDetails': 'Y'
}
response = requests.get(url_base, params=parameters)
response.status_code
# Outcome is 400 status code
# Out:
# 400

# %%
# Try to call the API (Required Parameters not provided)

url_base = 'https://developers.onemap.sg/commonapi/search'

parameters = {
    'searchval' : 'Adam Road Food Centre',
}
response = requests.get(url_base, params=parameters)
response.status_code
# Outcome is 400 series status code
# Out:
# 400

# %%
# Try to call the API (Correctly)

url_base = 'https://developers.onemap.sg/commonapi/search'

parameters = {
    'searchVal' : 'Adam Road Food Centre',
    'returnGeom': 'Y',
    'getAddrDetails': 'Y'
}
response = requests.get(url_base, params=parameters)
response.status_code
# Out:
# 200

# %%
# View the json text returned by the server
response.json()
# Out:
# {'found': 1,
#  'totalNumPages': 1,
#  'pageNum': 1,
#  'results': [{'SEARCHVAL': 'ADAM ROAD FOOD CENTRE',
#    'BLK_NO': '2',
#    'ROAD_NAME': 'ADAM ROAD',
#    'BUILDING': 'ADAM ROAD FOOD CENTRE',
#    'ADDRESS': '2 ADAM ROAD ADAM ROAD FOOD CENTRE SINGAPORE 289876',
#    'POSTAL': '289876',
#    'X': '25870.3018411137',
#    'Y': '34035.8644314632',
#    'LATITUDE': '1.3240827139625',
#    'LONGITUDE': '103.814182099841',
#    'LONGTITUDE': '103.814182099841'}]}

# %%
# Use .json_normalize from Pandas to convert the dictionary into a DataFrame 
pd.json_normalize(response.json()['results'])
# Out:
#                SEARCHVAL BLK_NO  ROAD_NAME               BUILDING  \
# 0  ADAM ROAD FOOD CENTRE      2  ADAM ROAD  ADAM ROAD FOOD CENTRE
#
#                                              ADDRESS  POSTAL  \
# 0  2 ADAM ROAD ADAM ROAD FOOD CENTRE SINGAPORE 28...  289876
#
#                   X                 Y         LATITUDE         LONGITUDE  \
# 0  25870.3018411137  34035.8644314632  1.3240827139625  103.814182099841
#
#          LONGTITUDE
# 0  103.814182099841

# %% [markdown]
# > 1. Loop through the **df_hawker** and find the geoinfo of each hawker from OneMap's SEARCH endpoint
# > 2. Store all the geoinfo as a new DataFrame

# %%
len(df_hawker)
# Out:
# 5

# %%
df_hawker_geoinfo = []

for row_index, row in df_hawker.iterrows():
    # Create a dictionary of the parameters
    parameters = {
        'searchVal' : row['name_of_centre'],
        'returnGeom': 'Y',
        'getAddrDetails': 'Y'
    }

    # Send the request via .get() method
    response = requests.get(url_base, params=parameters)

    # Check if the request is successful
    if response.status_code == 200:
        response_dict = response.json()
        # Check if there is at least 1 record
        if len(response_dict['results']) > 0:
            df_temp = pd.json_normalize(response_dict['results'])
            df_hawker_geoinfo.append(df_temp)
    else:
        print('The request failed and returned status code:' + str(response.status_code))

# %%
# Concatenate the records stored in multiple DataFrames into a single DataFrame
df_hawker_geoinfo = pd.concat(df_hawker_geoinfo, axis=0, ignore_index=True)
df_hawker_geoinfo
# Out:
#                  SEARCHVAL BLK_NO     ROAD_NAME                 BUILDING  \
# 0    ADAM ROAD FOOD CENTRE      2     ADAM ROAD    ADAM ROAD FOOD CENTRE
# 1  AMOY STREET FOOD CENTRE      7  MAXWELL ROAD  AMOY STREET FOOD CENTRE
# 2        BEDOK FOOD CENTRE      1    BEDOK ROAD        BEDOK FOOD CENTRE
# 3      BEO CRESCENT MARKET    38A  BEO CRESCENT      BEO CRESCENT MARKET
# 4       BERSEH FOOD CENTRE    166   JALAN BESAR       BERSEH FOOD CENTRE
#
#                                              ADDRESS  POSTAL  \
# 0  2 ADAM ROAD ADAM ROAD FOOD CENTRE SINGAPORE 28...  289876
# 1  7 MAXWELL ROAD AMOY STREET FOOD CENTRE SINGAPO...  069111
# 2    1 BEDOK ROAD BEDOK FOOD CENTRE SINGAPORE 469572  469572
# 3  38A BEO CRESCENT BEO CRESCENT MARKET SINGAPORE...  169982
# 4  166 JALAN BESAR BERSEH FOOD CENTRE SINGAPORE 2...  208877
#
#                   X                 Y          LATITUDE         LONGITUDE  \
# 0  25870.3018411137  34035.8644314632   1.3240827139625  103.814182099841
# 1   29483.955767219  29088.4261356071   1.2793398636571  103.846652482254
# 2  41595.4345044643   33623.132626934  1.32034716834128  103.955480570427
# 3  27336.1809281698   30137.891893005  1.28883089150258  103.827353892228
# 4  30623.1448179465  32184.9996254593  1.30734410946371  103.856888783769
#
#          LONGTITUDE
# 0  103.814182099841
# 1  103.846652482254
# 2  103.955480570427
# 3  103.827353892228
# 4  103.856888783769

# %%
len(df_hawker_geoinfo)
# Out:
# 5

# %% [markdown]
# # !! Your Turn !!

# %% [markdown]
# ## Replace the code marked as <..> COMPLETELY with your own.
# - The placeholder <..> is meant to be guidance for your answer.
# - It should not be restricting your solutions for the questions.
# - Feel free to add more lines or use less lines,
# - One placeholder does not mean that you can only insert one line of codes.

# %% [markdown]
# # Question 1
# > - Continue from the **df_hawker** and **df_hawker_geoinfo**, produce a new DataFrame **df_hawker_center**, <br>
# > where each row is a unique hawker center with all the columns both **df_hawker** and **df_hawker_geoinfo**
# > - The four columns "X", "Y", "LONGTITUDE", and "_id" must be excluded in the **df_hawker_center**
# > - Change all the column names into lower case

# %%
# Common column to merge on is the 'name of center' from the df_hawker dataframe and the SEARCHVAL columns
# from the df_hawker_geoinfo dataframe
# But first, let's we normalise the case of one of the commmon columns to upperer case
df_hawker['name_of_centre'] = df_hawker['name_of_centre'].apply(lambda x: x.upper())

# %%
#  Merge the two dataframes
df_hawker_center = df_hawker.merge(df_hawker_geoinfo, how='left', left_on='name_of_centre', right_on='SEARCHVAL')

# %%
# Drop columns X, Y and longtitude

df_hawker_center.drop(['X', 'Y', 'LONGTITUDE', '_id'], axis=1, inplace=True)

# %%
# Change all column names to lower case
df_hawker_center = df_hawker_center.rename(columns=str.lower)

df_hawker_center
# Out:
#                                   location_of_centre no_of_cooked_food_stalls  \
# 0                            2, Adam Road, S(289876)                       32
# 1  National Development Building, Annex B, Telok ...                      134
# 2                           1, Bedok Road, S(469572)                       32
# 3                       38A, Beo Crescent, S(169982)                       32
# 4                        166, Jalan Besar, S(208877)                       66
#
#   no_of_mkt_produce_stalls           name_of_centre type_of_centre  \
# 0                        0    ADAM ROAD FOOD CENTRE             HC
# 1                        1  AMOY STREET FOOD CENTRE             HC
# 2                        0        BEDOK FOOD CENTRE             HC
# 3                       62      BEO CRESCENT MARKET            MHC
# 4                        0       BERSEH FOOD CENTRE             HC
#
#   no_of_stalls       owner                searchval blk_no     road_name  \
# 0           32  Government    ADAM ROAD FOOD CENTRE      2     ADAM ROAD
# 1          135  Government  AMOY STREET FOOD CENTRE      7  MAXWELL ROAD
# 2           32  Government        BEDOK FOOD CENTRE      1    BEDOK ROAD
# 3           94  Government      BEO CRESCENT MARKET    38A  BEO CRESCENT
# 4           66  Government       BERSEH FOOD CENTRE    166   JALAN BESAR
#
#                   building                                            address  \
# 0    ADAM ROAD FOOD CENTRE  2 ADAM ROAD ADAM ROAD FOOD CENTRE SINGAPORE 28...
# 1  AMOY STREET FOOD CENTRE  7 MAXWELL ROAD AMOY STREET FOOD CENTRE SINGAPO...
# 2        BEDOK FOOD CENTRE    1 BEDOK ROAD BEDOK FOOD CENTRE SINGAPORE 469572
# 3      BEO CRESCENT MARKET  38A BEO CRESCENT BEO CRESCENT MARKET SINGAPORE...
# 4       BERSEH FOOD CENTRE  166 JALAN BESAR BERSEH FOOD CENTRE SINGAPORE 2...
#
#    postal          latitude         longitude
# 0  289876   1.3240827139625  103.814182099841
# 1  069111   1.2793398636571  103.846652482254
# 2  469572  1.32034716834128  103.955480570427
# 3  169982  1.28883089150258  103.827353892228
# 4  208877  1.30734410946371  103.856888783769

# %% [markdown]
# # Question 2

# %% [markdown]
# > Part A) <br>
# > Store the first 200 records from the Excel file located at **data > 0_raw_data > hdb_postal_to_stations.xlsx** into a DataFrame, called **df_mrt_subset**

# %%
df_mrt_subset = pd.read_excel('data\\0_raw_data\hdb_postal_to_stations.xlsx').head(200)

# %%
len(df_mrt_subset)
# Out:
# 200

# %%
df_mrt_subset.head()
# Out:
#      postal station_type  station_name  station_nearest_distance
# 0  560174.0          MRT  Yio Chu Kang               1098.719927
# 1  560541.0          MRT    Ang Mo Kio                806.155872
# 2  560163.0          MRT  Yio Chu Kang               1179.564586
# 3  560446.0          MRT    Ang Mo Kio                688.604642
# 4  560557.0          MRT    Ang Mo Kio                929.151815

# %%
df_mrt_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   postal                    200 non-null    object
#  1   station_type              200 non-null    object
#  2   station_name              200 non-null    object
#  3   station_nearest_distance  200 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 6.4+ KB

# %%
df_mrt_subset['postal']=df_mrt_subset['postal'].astype('float')
df_mrt_subset['postal']=df_mrt_subset['postal'].astype('int')

# %%
df_mrt_subset.head()
# Out:
#    postal station_type  station_name  station_nearest_distance
# 0  560174          MRT  Yio Chu Kang               1098.719927
# 1  560541          MRT    Ang Mo Kio                806.155872
# 2  560163          MRT  Yio Chu Kang               1179.564586
# 3  560446          MRT    Ang Mo Kio                688.604642
# 4  560557          MRT    Ang Mo Kio                929.151815

# %% [markdown]
# > Part B) <br>
# > - Retrieve the geoinfo using OneMap's API Endpoint 'https://developers.onemap.sg/commonapi/search', <br>
# > using the postal codes of the MRT stations
# > - Store the geoinfo for the MRT stations' postal code into DataFrame **df_mrt_geoinfo** <br>
# > 💡Hint: You will need to the remove the decimal point at the end of each postal code

# %%
df_mrt_geoinfo = []

for row_index, row in df_mrt_subset.iterrows():
    # Create a dictionary of the parameters
    parameters = {
        'searchVal' : row['postal'],
        'returnGeom': 'Y',
        'getAddrDetails': 'Y'
    }

    # Send the request via .get() method
    response = requests.get(url_base, params=parameters)

    # Check if the request is successful
    if response.status_code == 200:
        response_dict = response.json()
        # Check if there is at least 1 record
        if len(response_dict['results']) > 0:
            df_temp = pd.json_normalize(response_dict['results'])
            df_mrt_geoinfo.append(df_temp)
    else:
        print('The request failed and returned status code:' + str(response.status_code))

# %%
# Concatenate the records stored in multiple DataFrames into a single DataFrame
df_mrt_geoinfo = pd.concat(df_mrt_geoinfo, axis=0, ignore_index=True)
df_mrt_geoinfo
# Out:
#                                           SEARCHVAL BLK_NO  \
# 0                                 KEBUN BARU LINK 1    174
# 1                                   CHENG SAN GREEN    541
# 2                                    MY FIRST SKOOL    541
# 3          163 ANG MO KIO AVENUE 4 SINGAPORE 560163    163
# 4                                        FULL MARKS    163
# ..                                              ...    ...
# 236                                     SPRING VIEW   291B
# 237                                     NATURE VIEW   288D
# 238                         SKY VISTA @ BUKIT BATOK   113C
# 239  186 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650186    186
# 240  386 BUKIT BATOK WEST AVENUE 5 SINGAPORE 650386    386
#
#                      ROAD_NAME                 BUILDING  \
# 0          ANG MO KIO AVENUE 4        KEBUN BARU LINK 1
# 1         ANG MO KIO AVENUE 10          CHENG SAN GREEN
# 2         ANG MO KIO AVENUE 10           MY FIRST SKOOL
# 3          ANG MO KIO AVENUE 4                      NIL
# 4          ANG MO KIO AVENUE 4               FULL MARKS
# ..                         ...                      ...
# 236      BUKIT BATOK STREET 24              SPRING VIEW
# 237      BUKIT BATOK STREET 25              NATURE VIEW
# 238  BUKIT BATOK WEST AVENUE 6  SKY VISTA @ BUKIT BATOK
# 239  BUKIT BATOK WEST AVENUE 6                      NIL
# 240  BUKIT BATOK WEST AVENUE 5                      NIL
#
#                                                ADDRESS  POSTAL  \
# 0    174 ANG MO KIO AVENUE 4 KEBUN BARU LINK 1 SING...  560174
# 1    541 ANG MO KIO AVENUE 10 CHENG SAN GREEN SINGA...  560541
# 2    541 ANG MO KIO AVENUE 10 MY FIRST SKOOL SINGAP...  560541
# 3             163 ANG MO KIO AVENUE 4 SINGAPORE 560163  560163
# 4    163 ANG MO KIO AVENUE 4 FULL MARKS SINGAPORE 5...  560163
# ..                                                 ...     ...
# 236  291B BUKIT BATOK STREET 24 SPRING VIEW SINGAPO...  651291
# 237  288D BUKIT BATOK STREET 25 NATURE VIEW SINGAPO...  653288
# 238  113C BUKIT BATOK WEST AVENUE 6 SKY VISTA @ BUK...  653113
# 239     186 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650186  650186
# 240     386 BUKIT BATOK WEST AVENUE 5 SINGAPORE 650386  650386
#
#                     X                 Y          LATITUDE         LONGITUDE  \
# 0    28478.5794445509  39676.8076131288  1.37509746867904   103.83761896123
# 1     30482.026548801  39546.8847144619  1.37392239168826  103.855621371068
# 2     30482.026488265  39546.8841999061  1.37392238703482  103.855621370524
# 3     28540.623786686   39505.534986278  1.37354853919927  103.838176471398
# 4     28539.787784976  39505.8939948324  1.37355178595963  103.838168959329
# ..                ...               ...               ...               ...
# 236  19379.9538016999  36145.1296477765  1.34315699982096  103.755862270481
# 237  19758.0990471318  36437.7046699263  1.34580304817683  103.759260051639
# 238  18209.7822006959  36831.8956999574  1.34936750240674  103.745347358824
# 239  18069.3259528903  36523.7574556731  1.34658076680317  103.744085374214
# 240   19012.082054765  38443.1579966731  1.36393942184816  103.752556035691
#
#            LONGTITUDE
# 0     103.83761896123
# 1    103.855621371068
# 2    103.855621370524
# 3    103.838176471398
# 4    103.838168959329
# ..                ...
# 236  103.755862270481
# 237  103.759260051639
# 238  103.745347358824
# 239  103.744085374214
# 240  103.752556035691
#
# [241 rows x 11 columns]

# %% [markdown]
# # Question 3

# %% [markdown]
# > Part A) <br>
# > - Download all the records for HDB carpark info from the API https://data.gov.sg/dataset/hdb-carpark-information
# > - Store the records into a DataFrame, called **df_carpark**

# %%
url_base = 'https://data.gov.sg/api/action/datastore_search'

parameters = {
    'resource_id' : '139a3035-e624-4f56-b63f-89ae28d4ae4c',
}
response = requests.get(url_base, params=parameters)

# %%
# View the json text returned by the API server
response_dict = response.json()
response_dict
# Out:
# {'help': 'https://data.gov.sg/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'resource_id': '139a3035-e624-4f56-b63f-89ae28d4ae4c',
#   'fields': [{'type': 'int4', 'id': '_id'},
#    {'type': 'text', 'id': 'car_park_no'},
#    {'type': 'text', 'id': 'address'},
#    {'type': 'numeric', 'id': 'x_coord'},
#    {'type': 'numeric', 'id': 'y_coord'},
#    {'type': 'text', 'id': 'car_park_type'},
#    {'type': 'text', 'id': 'type_of_parking_system'},
#    {'type': 'text', 'id': 'short_term_parking'},
#    {'type': 'text', 'id': 'free_parking'},
#    {'type': 'text', 'id': 'night_parking'},
#    {'type': 'numeric', 'id': 'car_park_decks'},
#    {'type': 'numeric', 'id': 'gantry_height'},
#    {'type': 'text', 'id': 'car_park_basement'}],
#   'records': [{'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'BASEMENT CAR PARK',
#     'y_coord': '31490.4942',
#     'x_coord': '30314.7936',
#     'free_parking': 'NO',
#     'gantry_height': '1.80',
#     'car_park_basement': 'Y',
#     'night_parking': 'YES',
#     'address': 'BLK 270/271 ALBERT CENTRE BASEMENT CAR PARK',
#     'car_park_decks': '1',
#     '_id': 1,
#     'car_park_no': 'ACB',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '33695.5198',
#     'x_coord': '33758.4143',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.10',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 98A ALJUNIED CRESCENT',
#     'car_park_decks': '5',
#     '_id': 2,
#     'car_park_no': 'ACM',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '34500.3599',
#     'x_coord': '29257.7203',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 101 JALAN DUSUN',
#     'car_park_decks': '0',
#     '_id': 3,
#     'car_park_no': 'AH1',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': '7AM-7PM',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39012.6664',
#     'x_coord': '28185.4359',
#     'free_parking': 'NO',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'BLOCK 253 ANG MO KIO STREET 21',
#     'car_park_decks': '0',
#     '_id': 4,
#     'car_park_no': 'AK19',
#     'type_of_parking_system': 'COUPON PARKING'},
#    {'short_term_parking': 'NO',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38684.1754',
#     'x_coord': '29482.0290',
#     'free_parking': 'NO',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'BLK 302/348 ANG MO KIO ST 31',
#     'car_park_decks': '0',
#     '_id': 5,
#     'car_park_no': 'AK31',
#     'type_of_parking_system': 'COUPON PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39382.8134',
#     'x_coord': '29889.3457',
#     'free_parking': 'NO',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLOCK 513 ANG MO KIO ST 53',
#     'car_park_decks': '0',
#     '_id': 6,
#     'car_park_no': 'AK52',
#     'type_of_parking_system': 'COUPON PARKING'},
#    {'short_term_parking': '7AM-10.30PM',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39647.8906',
#     'x_coord': '29283.7324',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'BLOCK 728 ANG MO KIO AVE 6',
#     'car_park_decks': '0',
#     '_id': 7,
#     'car_park_no': 'AK6',
#     'type_of_parking_system': 'COUPON PARKING'},
#    {'short_term_parking': 'NO',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39851.6191',
#     'x_coord': '31397.2241',
#     'free_parking': 'NO',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'BLK 5022 TO 5095 ANG MO KIO INDUSTRIAL PARK 2',
#     'car_park_decks': '0',
#     '_id': 8,
#     'car_park_no': 'AK83',
#     'type_of_parking_system': 'COUPON PARKING'},
#    {'short_term_parking': 'NO',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '40616.8750',
#     'x_coord': '29674.8184',
#     'free_parking': 'NO',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'ANG MO KIO AVENUE 9',
#     'car_park_decks': '0',
#     '_id': 9,
#     'car_park_no': 'AK9',
#     'type_of_parking_system': 'COUPON PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '38973.9528',
#     'x_coord': '28777.0707',
#     'free_parking': 'NO',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 227 ANG MO KIO ST 23',
#     'car_park_decks': '6',
#     '_id': 10,
#     'car_park_no': 'AM14',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '39151.8344',
#     'x_coord': '28267.0582',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 256A ANG MO KIO STREET 21',
#     'car_park_decks': '2',
#     '_id': 11,
#     'car_park_no': 'AM16',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': '7AM-10.30PM',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '38619.9953',
#     'x_coord': '29257.6457',
#     'free_parking': 'NO',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'BLK 308C ANG MO KIO AVE 1',
#     'car_park_decks': '3',
#     '_id': 12,
#     'car_park_no': 'AM18',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '38989.9965',
#     'x_coord': '28134.9305',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 260 ANG MO KIO ST 21',
#     'car_park_decks': '6',
#     '_id': 13,
#     'car_park_no': 'AM19',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '38526.8611',
#     'x_coord': '29421.1502',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 309B ANG MO KIO ST 31',
#     'car_park_decks': '12',
#     '_id': 14,
#     'car_park_no': 'AM20',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '38514.7606',
#     'x_coord': '29595.2539',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 316B ANG MO KIO STREET 31',
#     'car_park_decks': '12',
#     '_id': 15,
#     'car_park_no': 'AM22',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '39172.0389',
#     'x_coord': '28117.7689',
#     'free_parking': 'NO',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 255A ANG MO KIO ST 21',
#     'car_park_decks': '2',
#     '_id': 16,
#     'car_park_no': 'AM32',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '38959.5487',
#     'x_coord': '30669.2379',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 455 ANG MO KIO ST 44',
#     'car_park_decks': '7',
#     '_id': 17,
#     'car_park_no': 'AM43',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '39354.0323',
#     'x_coord': '30234.4145',
#     'free_parking': 'NO',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 588 ANG MO KIO STREET 52',
#     'car_park_decks': '5',
#     '_id': 18,
#     'car_park_no': 'AM46',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '39103.7605',
#     'x_coord': '29489.0250',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 700 ANG MO KIO AVE 6',
#     'car_park_decks': '12',
#     '_id': 19,
#     'car_park_no': 'AM51',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '39274.2740',
#     'x_coord': '30201.2360',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 590 ANG MO KIO ST 51',
#     'car_park_decks': '12',
#     '_id': 20,
#     'car_park_no': 'AM64',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '39370.6063',
#     'x_coord': '30004.2224',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 596 ANG MO KIO STREEET 52',
#     'car_park_decks': '12',
#     '_id': 21,
#     'car_park_no': 'AM79',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '39184.6976',
#     'x_coord': '28950.7223',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 130A ANG MO KIO ST 12',
#     'car_park_decks': '4',
#     '_id': 22,
#     'car_park_no': 'AM80',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '39294.4158',
#     'x_coord': '28960.3285',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 132A ANG MO KIO ST 12',
#     'car_park_decks': '4',
#     '_id': 23,
#     'car_park_no': 'AM81',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '38457.9118',
#     'x_coord': '29961.0968',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 352A ANG MO KIO STREET 32',
#     'car_park_decks': '12',
#     '_id': 24,
#     'car_park_no': 'AM96',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'NO',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '31801.6379',
#     'x_coord': '22359.0217',
#     'free_parking': 'NO',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': '3 AND 5 DOVER ROAD',
#     'car_park_decks': '0',
#     '_id': 25,
#     'car_park_no': 'AR1L',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '31687.9608',
#     'x_coord': '22474.2050',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 2A DOVER ROAD',
#     'car_park_decks': '10',
#     '_id': 26,
#     'car_park_no': 'AR1M',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'NO',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '32026.8288',
#     'x_coord': '22194.6359',
#     'free_parking': 'NO',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'BLK 26 AND 27 DOVER CRESCENT',
#     'car_park_decks': '0',
#     '_id': 27,
#     'car_park_no': 'AR2L',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '31896.9749',
#     'x_coord': '22252.4860',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 28 DOVER CRESCENT',
#     'car_park_decks': '16',
#     '_id': 28,
#     'car_park_no': 'AR2M',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '32184.9758',
#     'x_coord': '22562.8641',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 19A DOVER CRESCENT',
#     'car_park_decks': '12',
#     '_id': 29,
#     'car_park_no': 'AR5M',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'NO',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '32015.1518',
#     'x_coord': '22688.3753',
#     'free_parking': 'NO',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': '12 TO 14 DOVER CLOSE EAST',
#     'car_park_decks': '0',
#     '_id': 30,
#     'car_park_no': 'AR7L',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '31900.5591',
#     'x_coord': '22643.9533',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '2.15',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 12A DOVER CLOSE EAST',
#     'car_park_decks': '7',
#     '_id': 31,
#     'car_park_no': 'AR7M',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': '7AM-10.30PM',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '32178.4360',
#     'x_coord': '22448.9368',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'BLK 20/22/23 DOVER CRESCENT',
#     'car_park_decks': '0',
#     '_id': 32,
#     'car_park_no': 'AR9',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '29778.7266',
#     'x_coord': '24649.7520',
#     'free_parking': 'NO',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 120/120A/121-127 ALEXANDRA VILLAGE',
#     'car_park_decks': '0',
#     '_id': 33,
#     'car_park_no': 'AV1',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '29704.4978',
#     'x_coord': '24941.5778',
#     'free_parking': 'NO',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 1001/1010 BUKIT MERAH LANE 1/3',
#     'car_park_decks': '0',
#     '_id': 34,
#     'car_park_no': 'AV2',
#     'type_of_parking_system': 'COUPON PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38749.8516',
#     'x_coord': '28934.1777',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 215 ANG MO KIO STREET 22',
#     'car_park_decks': '0',
#     '_id': 35,
#     'car_park_no': 'A1',
#     'type_of_parking_system': 'COUPON PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38962.0000',
#     'x_coord': '29247.0300',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 201/202 ANG MO KIO STREET 22',
#     'car_park_decks': '0',
#     '_id': 36,
#     'car_park_no': 'A10',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39996.3712',
#     'x_coord': '29033.1895',
#     'free_parking': 'NO',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 650 ANG MO KIO STREET 61',
#     'car_park_decks': '0',
#     '_id': 37,
#     'car_park_no': 'A100',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38785.3600',
#     'x_coord': '28541.1400',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 223/226/226A-226D ANG MO KIO ST 22',
#     'car_park_decks': '0',
#     '_id': 38,
#     'car_park_no': 'A11',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38948.3800',
#     'x_coord': '28596.1400',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 229/230 ANG MO KIO ST 22',
#     'car_park_decks': '0',
#     '_id': 39,
#     'car_park_no': 'A12',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38892.0300',
#     'x_coord': '28388.5100',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 232/233 ANG MO KIO ST 22',
#     'car_park_decks': '0',
#     '_id': 40,
#     'car_park_no': 'A13',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38777.8500',
#     'x_coord': '28790.0200',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 226E-226H ANG MO KIO ST 22',
#     'car_park_decks': '0',
#     '_id': 41,
#     'car_park_no': 'A15',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38697.0700',
#     'x_coord': '29082.5900',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 206/207 ANG MO KIO STREET 22',
#     'car_park_decks': '0',
#     '_id': 42,
#     'car_park_no': 'A2',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38554.0251',
#     'x_coord': '29684.7366',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 304/307/319 ANG MO KIO ST 31',
#     'car_park_decks': '0',
#     '_id': 43,
#     'car_park_no': 'A20',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38906.1139',
#     'x_coord': '29446.1477',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 325/326/301 ANG MO KIO STREET 31',
#     'car_park_decks': '0',
#     '_id': 44,
#     'car_park_no': 'A21',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '38818.5301',
#     'x_coord': '29735.5099',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '1.90',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 347A ANG MO KIO AVENUE 3',
#     'car_park_decks': '10',
#     '_id': 45,
#     'car_park_no': 'A23',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38533.0200',
#     'x_coord': '29789.4100',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 338/340 ANG MO KIO ST 32',
#     'car_park_decks': '0',
#     '_id': 46,
#     'car_park_no': 'A24',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38313.6296',
#     'x_coord': '30037.5660',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 330/337 ANG MO KIO AVE 8',
#     'car_park_decks': '0',
#     '_id': 47,
#     'car_park_no': 'A25',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39419.4700',
#     'x_coord': '28236.9300',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 113/114/118 ANG MO KIO AVE 4',
#     'car_park_decks': '0',
#     '_id': 48,
#     'car_park_no': 'A26',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39153.3000',
#     'x_coord': '28556.6700',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '5.40',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 108/109/110 ANG MO KIO ST 11',
#     'car_park_decks': '0',
#     '_id': 49,
#     'car_park_no': 'A27',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39295.5961',
#     'x_coord': '28461.3669',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 103/105/107 ANG MO KIO ST 11',
#     'car_park_decks': '0',
#     '_id': 50,
#     'car_park_no': 'A28',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38806.4544',
#     'x_coord': '29713.5035',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 347 ANG MO KIO AVENUE 3',
#     'car_park_decks': '0',
#     '_id': 51,
#     'car_park_no': 'A29',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39222.5981',
#     'x_coord': '29012.7631',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 129/134 ANG MO KIO STREET 12',
#     'car_park_decks': '0',
#     '_id': 52,
#     'car_park_no': 'A30',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': '7AM-10.30PM',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39137.2773',
#     'x_coord': '29050.5605',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'BLK 133 ANG MO KIO STREET 12',
#     'car_park_decks': '0',
#     '_id': 53,
#     'car_park_no': 'A30A',
#     'type_of_parking_system': 'COUPON PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39163.0400',
#     'x_coord': '29155.3200',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 119/128 ANG MO KIO ST 12',
#     'car_park_decks': '0',
#     '_id': 54,
#     'car_park_no': 'A31',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': '7AM-10.30PM',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39318.7539',
#     'x_coord': '29150.6699',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'BLK 125/126 ANG MO KIO STREET 12',
#     'car_park_decks': '0',
#     '_id': 55,
#     'car_park_no': 'A31A',
#     'type_of_parking_system': 'COUPON PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39115.4784',
#     'x_coord': '28152.8391',
#     'free_parking': 'NO',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 253/254 ANG MO KIO STREET 21',
#     'car_park_decks': '0',
#     '_id': 56,
#     'car_park_no': 'A33',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38931.4300',
#     'x_coord': '30042.0000',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 422/425 ANG MO KIO ST 42',
#     'car_park_decks': '0',
#     '_id': 57,
#     'car_park_no': 'A34',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38963.4900',
#     'x_coord': '30310.6600',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 426/428/435 ANG MO KIO ST 43',
#     'car_park_decks': '0',
#     '_id': 58,
#     'car_park_no': 'A35',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38715.8847',
#     'x_coord': '30443.9088',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 436/443/445 ANG MO KIO ST 43',
#     'car_park_decks': '0',
#     '_id': 59,
#     'car_park_no': 'A36',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38904.5192',
#     'x_coord': '30474.8188',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 446/449/453 ANG MO KIO ST 43',
#     'car_park_decks': '0',
#     '_id': 60,
#     'car_park_no': 'A37',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38445.7028',
#     'x_coord': '30367.0774',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 407/410/421 ANG MO KIO AVE 10',
#     'car_park_decks': '0',
#     '_id': 61,
#     'car_park_no': 'A38',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38134.6900',
#     'x_coord': '30309.6300',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 401/405 ANG MO KIO AVE 10',
#     'car_park_decks': '0',
#     '_id': 62,
#     'car_park_no': 'A39',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38636.7578',
#     'x_coord': '28876.2363',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 217/220 ANG MO KIO AVENUE 1',
#     'car_park_decks': '0',
#     '_id': 63,
#     'car_park_no': 'A4',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38267.9500',
#     'x_coord': '30633.4700',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '9.99',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 471/476 ANG MO KIO ST 44',
#     'car_park_decks': '0',
#     '_id': 64,
#     'car_park_no': 'A40',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38553.3200',
#     'x_coord': '30627.9600',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 466/470 ANG MO KIO ST 44',
#     'car_park_decks': '0',
#     '_id': 65,
#     'car_park_no': 'A41',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38735.0223',
#     'x_coord': '30675.9559',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 461/465 ANG MO KIO ST 44',
#     'car_park_decks': '0',
#     '_id': 66,
#     'car_park_no': 'A42',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38670.5100',
#     'x_coord': '30887.7800',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 457/458/460 ANG MO KIO ST 44',
#     'car_park_decks': '0',
#     '_id': 67,
#     'car_park_no': 'A43',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38804.1956',
#     'x_coord': '30856.9781',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 459/456 ANG MO KIO ST 44',
#     'car_park_decks': '0',
#     '_id': 68,
#     'car_park_no': 'A44',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39214.6400',
#     'x_coord': '30438.5300',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 570/578 ANG MO KIO ST 51',
#     'car_park_decks': '0',
#     '_id': 69,
#     'car_park_no': 'A45',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39174.8899',
#     'x_coord': '30885.4750',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 562/565/560 ANG MO KIO STREET 54',
#     'car_park_decks': '0',
#     '_id': 70,
#     'car_park_no': 'A47',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39154.2200',
#     'x_coord': '30374.1800',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 571/73 ANG MO KIO ST 51',
#     'car_park_decks': '0',
#     '_id': 71,
#     'car_park_no': 'A48',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39260.1900',
#     'x_coord': '30724.1600',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 555/559 ANG MO KIO STREET 54',
#     'car_park_decks': '0',
#     '_id': 72,
#     'car_park_no': 'A49',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39392.0900',
#     'x_coord': '30703.2900',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 548/552/556 ANG MO KIO STREET 54',
#     'car_park_decks': '0',
#     '_id': 73,
#     'car_park_no': 'A50',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39054.6321',
#     'x_coord': '28117.6053',
#     'free_parking': 'NO',
#     'gantry_height': '5.40',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 252/253A ANG MO KIO STREET 21',
#     'car_park_decks': '0',
#     '_id': 74,
#     'car_park_no': 'A51',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39155.7785',
#     'x_coord': '29513.9566',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 701/716 ANG MO KIO AVE 3/6',
#     'car_park_decks': '0',
#     '_id': 75,
#     'car_park_no': 'A52',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'NO',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39033.6150',
#     'x_coord': '29426.2389',
#     'free_parking': 'NO',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'BLK 700B/ 700C ANG MO KIO AVE 3/6',
#     'car_park_decks': '0',
#     '_id': 76,
#     'car_park_no': 'A52L',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'MULTI-STOREY CAR PARK',
#     'y_coord': '39208.8091',
#     'x_coord': '29508.9218',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '1.80',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 712A ANG MO KIO AVE 3/6',
#     'car_park_decks': '14',
#     '_id': 77,
#     'car_park_no': 'A53',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39382.3378',
#     'x_coord': '29401.8671',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 727/728 ANG MO KIO AVE 6',
#     'car_park_decks': '0',
#     '_id': 78,
#     'car_park_no': 'A54',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39515.4900',
#     'x_coord': '29485.5000',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 729/730 ANG MO KIO AVE 6/8',
#     'car_park_decks': '0',
#     '_id': 79,
#     'car_park_no': 'A55',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39411.5653',
#     'x_coord': '29538.8470',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 725/730 ANG MO KIO AVE 8',
#     'car_park_decks': '0',
#     '_id': 80,
#     'car_park_no': 'A56',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39336.4776',
#     'x_coord': '29518.5871',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 720/723 ANG MO KIO AVE 8',
#     'car_park_decks': '0',
#     '_id': 81,
#     'car_park_no': 'A57',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39372.6800',
#     'x_coord': '29603.1600',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 721/722 ANG MO KIO AVE 8',
#     'car_park_decks': '0',
#     '_id': 82,
#     'car_park_no': 'A58',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39543.9937',
#     'x_coord': '30762.2950',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '3.80',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 547/551 ANG MO KIO ST 54',
#     'car_park_decks': '0',
#     '_id': 83,
#     'car_park_no': 'A59',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39606.8281',
#     'x_coord': '30514.5273',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 540/546 ANG MO KIO ST 54',
#     'car_park_decks': '0',
#     '_id': 84,
#     'car_park_no': 'A60',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39574.3100',
#     'x_coord': '30096.8200',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '9.99',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 520/534/529 ANG MO KIO AVE 5/10',
#     'car_park_decks': '0',
#     '_id': 85,
#     'car_park_no': 'A61',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39690.0448',
#     'x_coord': '29789.5613',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '5.40',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 501/513/508 ANG MO KIO ST 52/53',
#     'car_park_decks': '0',
#     '_id': 86,
#     'car_park_no': 'A63',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39172.3075',
#     'x_coord': '30241.6957',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '5.40',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 584/586 ANG MO KIO ST 51',
#     'car_park_decks': '0',
#     '_id': 87,
#     'car_park_no': 'A64',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39226.9700',
#     'x_coord': '30904.4600',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 558/560 ANG MO KIO STREET 54',
#     'car_park_decks': '0',
#     '_id': 88,
#     'car_park_no': 'A65',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '40279.1600',
#     'x_coord': '28260.6400',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '5.40',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 601/604/603 ANG MO KIO AVE 5',
#     'car_park_decks': '0',
#     '_id': 89,
#     'car_park_no': 'A66',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '40184.2200',
#     'x_coord': '28499.2700',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 605/612 ANG MO KIO AVE 4/5',
#     'car_park_decks': '0',
#     '_id': 90,
#     'car_park_no': 'A67',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '40428.7342',
#     'x_coord': '28727.3335',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 620/624/626 ANG MO KIO ST 61',
#     'car_park_decks': '0',
#     '_id': 91,
#     'car_park_no': 'A68',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '40400.4100',
#     'x_coord': '28960.0600',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '5.40',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 623/625/627 ANG MO KIO ST 61',
#     'car_park_decks': '0',
#     '_id': 92,
#     'car_park_no': 'A69',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '38935.4059',
#     'x_coord': '28888.4313',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 212/213 ANG MO KIO STREET 23',
#     'car_park_decks': '0',
#     '_id': 93,
#     'car_park_no': 'A7',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '40287.5326',
#     'x_coord': '28755.4887',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '9.99',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 629/626 ANG MO KIO AVE 4',
#     'car_park_decks': '0',
#     '_id': 94,
#     'car_park_no': 'A70',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '40219.9110',
#     'x_coord': '28826.1219',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '5.40',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 628/632 ANG MO KIO ST 61',
#     'car_park_decks': '0',
#     '_id': 95,
#     'car_park_no': 'A71',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '40303.0500',
#     'x_coord': '29136.4400',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '5.40',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 633/640 ANG MO KIO ST 61',
#     'car_park_decks': '0',
#     '_id': 96,
#     'car_park_no': 'A72',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'NO',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '28847.7781',
#     'x_coord': '28733.8679',
#     'free_parking': 'NO',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'NO',
#     'address': 'BLK 1/7 EVERTON PARK',
#     'car_park_decks': '0',
#     '_id': 612,
#     'car_park_no': 'EPL',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '40091.5441',
#     'x_coord': '28835.3369',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 641/645 ANG MO KIO ST 61',
#     'car_park_decks': '0',
#     '_id': 97,
#     'car_park_no': 'A73',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '40069.8164',
#     'x_coord': '29166.9700',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '0.00',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 646/649 ANG MO KIO ST 61',
#     'car_park_decks': '0',
#     '_id': 98,
#     'car_park_no': 'A74',
#     'type_of_parking_system': 'ELECTRONIC PARKING'},
#    {'short_term_parking': 'WHOLE DAY',
#     'car_park_type': 'SURFACE CAR PARK',
#     'y_coord': '39798.9610',
#     'x_coord': '28597.1669',
#     'free_parking': 'SUN & PH FR 7AM-10.30PM',
#     'gantry_height': '4.50',
#     'car_park_basement': 'N',
#     'night_parking': 'YES',
#     'address': 'BLK 177/182 ANG MO KIO AVE 4',
#     'car_park_decks': '0',
#     '_id': 99,
#     'car_park_no': 'A75',
#     'type_of_parking_system': 'ELECTRONIC PARKING'}],
#   '_links': {'start': '/api/action/datastore_search?resource_id=139a3035-e624-4f56-b63f-89ae28d4ae4c',
#    'next': '/api/action/datastore_search?offset=100&resource_id=139a3035-e624-4f56-b63f-89ae28d4ae4c'},
#   'total': 2183}}

# %%
# Traverse the dictionary to the level where the main records are located
response_dict['result']['total']
# Out:
# 2183

# %%
# Traverse the dictionary to the level where the main records are located
records = response_dict['result']['records']

# Check the number of records
len(records)
# Out:
# 100

# %%
# Use .json_normalize from Pandas to convert the dictionary into a DataFrame
df_carpark = pd.json_normalize(records)

df_carpark
# Out:
#    short_term_parking          car_park_type     y_coord     x_coord  \
# 0           WHOLE DAY      BASEMENT CAR PARK  31490.4942  30314.7936
# 1           WHOLE DAY  MULTI-STOREY CAR PARK  33695.5198  33758.4143
# 2           WHOLE DAY       SURFACE CAR PARK  34500.3599  29257.7203
# 3             7AM-7PM       SURFACE CAR PARK  39012.6664  28185.4359
# 4                  NO       SURFACE CAR PARK  38684.1754  29482.0290
# ..                ...                    ...         ...         ...
# 95          WHOLE DAY       SURFACE CAR PARK  40303.0500  29136.4400
# 96                 NO       SURFACE CAR PARK  28847.7781  28733.8679
# 97          WHOLE DAY       SURFACE CAR PARK  40091.5441  28835.3369
# 98          WHOLE DAY       SURFACE CAR PARK  40069.8164  29166.9700
# 99          WHOLE DAY       SURFACE CAR PARK  39798.9610  28597.1669
#
#                free_parking gantry_height car_park_basement night_parking  \
# 0                        NO          1.80                 Y           YES
# 1   SUN & PH FR 7AM-10.30PM          2.10                 N           YES
# 2   SUN & PH FR 7AM-10.30PM          0.00                 N           YES
# 3                        NO          0.00                 N            NO
# 4                        NO          0.00                 N            NO
# ..                      ...           ...               ...           ...
# 95  SUN & PH FR 7AM-10.30PM          5.40                 N           YES
# 96                       NO          4.50                 N            NO
# 97  SUN & PH FR 7AM-10.30PM          0.00                 N           YES
# 98  SUN & PH FR 7AM-10.30PM          0.00                 N           YES
# 99  SUN & PH FR 7AM-10.30PM          4.50                 N           YES
#
#                                         address car_park_decks  _id  \
# 0   BLK 270/271 ALBERT CENTRE BASEMENT CAR PARK              1    1
# 1                     BLK 98A ALJUNIED CRESCENT              5    2
# 2                           BLK 101 JALAN DUSUN              0    3
# 3                BLOCK 253 ANG MO KIO STREET 21              0    4
# 4                  BLK 302/348 ANG MO KIO ST 31              0    5
# ..                                          ...            ...  ...
# 95                 BLK 633/640 ANG MO KIO ST 61              0   96
# 96                         BLK 1/7 EVERTON PARK              0  612
# 97                 BLK 641/645 ANG MO KIO ST 61              0   97
# 98                 BLK 646/649 ANG MO KIO ST 61              0   98
# 99                 BLK 177/182 ANG MO KIO AVE 4              0   99
#
#    car_park_no type_of_parking_system
# 0          ACB     ELECTRONIC PARKING
# 1          ACM     ELECTRONIC PARKING
# 2          AH1     ELECTRONIC PARKING
# 3         AK19         COUPON PARKING
# 4         AK31         COUPON PARKING
# ..         ...                    ...
# 95         A72     ELECTRONIC PARKING
# 96         EPL     ELECTRONIC PARKING
# 97         A73     ELECTRONIC PARKING
# 98         A74     ELECTRONIC PARKING
# 99         A75     ELECTRONIC PARKING
#
# [100 rows x 13 columns]

# %% [markdown]
# > Part B)** - Challenging Question [Optional] <br>
# > - Check the number of records in **df_carpark**
# > - You will realize the total records on data.gov.sg is 2,183 records, but **df_carpark**only has 100 records
# > - This is because it's common for API return a "page" of results per call. In this case, the API returns 100 records per page.
# > - If you check *response.json()['result']['_links']*, you will see there are two links, the "next" link shows how to retrieve the next 100 records
# > - Find a way to download all 2,183 records and store into the dataframe **df_carparks**
#
# > hint: you can use anything that you have learnt so far to achieve this

# %%
response.json()['result']['_links']
# Out:
# {'start': '/api/action/datastore_search?resource_id=139a3035-e624-4f56-b63f-89ae28d4ae4c',
#  'next': '/api/action/datastore_search?offset=100&resource_id=139a3035-e624-4f56-b63f-89ae28d4ae4c'}

# %%
url_base = 'https://data.gov.sg/api/action/datastore_search'


# Use enter a large number in the limit parameter to retrieve all the records
parameters = {
    'resource_id' : '139a3035-e624-4f56-b63f-89ae28d4ae4c',
    'limit' : 1000000
}
response = requests.get(url_base, params=parameters)

response_dict = response.json()

records = response_dict['result']['records']

len(records)
# Out:
# 2183

# %%
# Use .json_normalize from Pandas to convert the dictionary into a DataFrame
df_carparks = pd.json_normalize(records)

len(df_carparks)
# Out:
# 2183

# %% [markdown]
# ## Method 2:  Looping through every 100 records

# %%
#  Do first run to fetch total number of rows dynamically
 
url_base = 'https://data.gov.sg/api/action/datastore_search'

# Use enter a large number in the limit parameter to retrieve all the records
parameters = {
    'resource_id' : '139a3035-e624-4f56-b63f-89ae28d4ae4c',
}

response = requests.get(url_base, params=parameters)

# View the json text returned by the API server
response_dict = response.json()
response_dict

# Traverse the dictionary to the level where the main records are located
total_number_of_rows = response_dict['result']['total']

total_number_of_rows
# Out:
# 2183

# %%
#  Iterate through the API call which imits to 100 records per request.
 
resource_id = '139a3035-e624-4f56-b63f-89ae28d4ae4c'

df_carpark = []

for i in range(0, total_number_of_rows, 100):
  parameters = {
    'resource_id' : resource_id,
    'offset': i 
    }
  
  url_base = 'https://data.gov.sg/api/action/datastore_search'
  
  response = requests.get(url_base, params=parameters)

  # View the json text returned by the API server
  response_dict = response.json()
  records = response_dict['result']['records']

  df_temp = pd.json_normalize(records)

  df_carpark.append(df_temp)

# %%
len(df_carpark)
# Out:
# 22

# %%
# Concatenate the records stored in multiple DataFrames into a single DataFrame
df_carpark = pd.concat(df_carpark, axis=0, ignore_index=True)
df_carpark
# Out:
#      short_term_parking          car_park_type     y_coord     x_coord  \
# 0             WHOLE DAY      BASEMENT CAR PARK  31490.4942  30314.7936
# 1             WHOLE DAY  MULTI-STOREY CAR PARK  33695.5198  33758.4143
# 2             WHOLE DAY       SURFACE CAR PARK  34500.3599  29257.7203
# 3               7AM-7PM       SURFACE CAR PARK  39012.6664  28185.4359
# 4                    NO       SURFACE CAR PARK  38684.1754  29482.0290
# ...                 ...                    ...         ...         ...
# 2178          WHOLE DAY  MULTI-STOREY CAR PARK  45576.0125  29850.1522
# 2179          WHOLE DAY  MULTI-STOREY CAR PARK  45166.4820  30057.2209
# 2180          WHOLE DAY       SURFACE CAR PARK  45686.2734  27772.9219
# 2181          WHOLE DAY  MULTI-STOREY CAR PARK  45679.7181  29935.5818
# 2182          WHOLE DAY       SURFACE CAR PARK  45507.8047  28077.2305
#
#                  free_parking gantry_height car_park_basement night_parking  \
# 0                          NO          1.80                 Y           YES
# 1     SUN & PH FR 7AM-10.30PM          2.10                 N           YES
# 2     SUN & PH FR 7AM-10.30PM          0.00                 N           YES
# 3                          NO          0.00                 N            NO
# 4                          NO          0.00                 N            NO
# ...                       ...           ...               ...           ...
# 2178  SUN & PH FR 7AM-10.30PM          2.15                 N           YES
# 2179  SUN & PH FR 7AM-10.30PM          2.15                 N           YES
# 2180  SUN & PH FR 7AM-10.30PM          4.50                 N           YES
# 2181  SUN & PH FR 7AM-10.30PM          2.15                 N           YES
# 2182  SUN & PH FR 7AM-10.30PM          4.50                 N           YES
#
#                                           address car_park_decks   _id  \
# 0     BLK 270/271 ALBERT CENTRE BASEMENT CAR PARK              1     1
# 1                       BLK 98A ALJUNIED CRESCENT              5     2
# 2                             BLK 101 JALAN DUSUN              0     3
# 3                  BLOCK 253 ANG MO KIO STREET 21              0     4
# 4                    BLK 302/348 ANG MO KIO ST 31              0     5
# ...                                           ...            ...   ...
# 2178                      BLK 461 YISHUN AVENUE 6             10  2179
# 2179                         BLK 468 YISHUN ST 43              4  2180
# 2180     BLK 731/746 YISHUN STREET 71,72/AVENUE 5              0  2181
# 2181                         BLK 478 YISHUN ST 42             11  2182
# 2182                 BLK 747/752 YISHUN STREET 72              0  2183
#
#      car_park_no type_of_parking_system
# 0            ACB     ELECTRONIC PARKING
# 1            ACM     ELECTRONIC PARKING
# 2            AH1     ELECTRONIC PARKING
# 3           AK19         COUPON PARKING
# 4           AK31         COUPON PARKING
# ...          ...                    ...
# 2178        Y77M     ELECTRONIC PARKING
# 2179        Y78M     ELECTRONIC PARKING
# 2180          Y8     ELECTRONIC PARKING
# 2181        Y82M     ELECTRONIC PARKING
# 2182          Y9     ELECTRONIC PARKING
#
# [2183 rows x 13 columns]
